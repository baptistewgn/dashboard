# %%
import pandas as pd
import datetime as dt

# Pour éviter de récupérer des données partielles du jour actuel lors d'exécutions tardives,
# définir end à hier (date d'aujourd'hui - 1 jour)

start_date = "2020-01-01"
last_ts = "2026-03-19"
start=last_ts if last_ts is not None else start_date

# %%
end_date = pd.Timestamp.now().normalize() - pd.Timedelta(days=1)
end=end_date.strftime("%Y-%m-%d")

# %%
print(start)
print(end)
# Out:
# 2026-03-19
# 2026-03-19
