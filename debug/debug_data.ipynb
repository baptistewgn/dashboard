# %%
import pandas as pd

# %%
pd.Timestamp.now().normalize()-pd.Timedelta(days=1)
# Out:
# Timestamp('2026-03-23 00:00:00')

# %%
import pandas as pd

path = "/Users/bwgn/Documents/3_local_dev/dev/dashboard_v0/data/raw_prices.parquet"

rp = pd.read_parquet(path)
print(rp)
# Out:
# Empty DataFrame
# Columns: [BTC-USD, DX-Y.NYB, ETH-USD, ^GSPC, ^TNX, ^VIX]
# Index: []

# %%
path = "/Users/bwgn/Documents/3_local_dev/dev/dashboard/data/features.parquet"

ft = pd.read_parquet(path)
print(ft)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 path = "/Users/bwgn/Documents/3_local_dev/dev/dashboard/data/features.parquet"
# ----> 3 ft = pd.read_parquet(path)
#       4 print(ft)
#
# File ~/Documents/3_local_dev/dev/dashboard_v0/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:671, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     668 impl = get_engine(engine)
#     669 check_dtype_backend(dtype_backend)
# --> 671 return impl.read(
#     672     path,
#     673     columns=columns,
#     674     filters=filters,
#     675     storage_options=storage_options,
#     676     dtype_backend=dtype_backend,
#     677     filesystem=filesystem,
#     678     to_pandas_kwargs=to_pandas_kwargs,
#     679     **kwargs,
#     680 )
#
# ...

# %%
ft.columns

# %%
ft[['BTC-USD_ret_5d', 'ETH-USD_ret_5d', '^GSPC_ret_5d', '^TNX_ret_5d','^VIX_ret_5d']]

# %%
rp[['^GSPC', '^TNX','^VIX']].tail(6)
